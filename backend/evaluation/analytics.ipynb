# %% [markdown]
# # LASSO Python
# ## MBPP Evaluation Analytics
# This notebook showcases how a data analyst can use LASSO Python to collect dynamic information about Python code implementations.
# By using data from an Apache Ignite cache that was filled by LASSO Python, the analyst can easily deduce interesting information, such as correctness of the code, execution times, or coverage data.
# Both the tests and the Python code implementations used in this example stem from the Mostly Basic Python Problems (MBPP) dataset. MBPP is a dataset consisting of crowd-sourced Python programming problems. Each task consists of a description, a code solution and multiple test cases. By using LASSO Python, multiple of these tests were replicated with the results shown in this notebook. More information on MBPP can be found here: https://github.com/google-research/google-research/tree/master/mbpp

# %%
# Import result csv that was generated by LASSO Python and extracted from the Apache Ignite cache
import pandas as pd

file_path = './evaluation_results.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                             EXECUTIONID ABSTRACTIONID  ACTIONID  ARENAID  \
# 0  e2009edf-95e1-4aa0-89e0-64c4d7419bff         Task8       NaN  execute
# 1  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task90       NaN  execute
# 2  6f41b57d-c704-4331-af4f-b03a54fb8fa7       Task106       NaN  execute
# 3  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task95       NaN  execute
# 4  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task74       NaN  execute
#
#     SHEETID                          SYSTEMID VARIANTID  \
# 0    8.xlsx  562286dcbbd409d0318a556a81e60e7e  original
# 1   90.xlsx  fd1b0543b2a0c513e31b105f4211421b  original
# 2  106.xlsx                               NaN  original
# 3   95.xlsx                               NaN  original
# 4   74.xlsx  c2c26f364a152e5f2b73f1851a6e7048  original
#
#                                     ADAPTERID  X   Y  \
# 0          0('square_nums', 'square_nums', 0) -1   9
# 1                  0('len_log', 'len_log', 0)  1   4
# 2        0('create', 'createPythonObject', 0)  3   5
# 3        0('create', 'createPythonObject', 0)  4  11
# 4  0('is_samepatterns', 'is_samepatterns', 0) -1   3
#
#                                 TYPE    VALUE RAWVALUE      VALUETYPE  \
# 0      metrics_covered_lines_in_file        2        2  <class 'int'>
# 1                                 op  len_log  len_log       function
# 2                        input_value       10       10  <class 'str'>
# 3                        input_value        4        4  <class 'int'>
# 4  metrics_covered_lines_in_function       17       17  <class 'int'>
#
#                                         LASTMODIFIED  EXECUTIONTIME
# 0  (datetime.datetime(2024, 9, 13, 18, 30, 1, 263...             -1
# 1  (datetime.datetime(2024, 9, 13, 21, 34, 54, 75...            217
# 2  (datetime.datetime(2024, 9, 13, 21, 36, 49, 53...             -1
# 3  (datetime.datetime(2024, 9, 13, 21, 35, 43, 66...             -1
# 4  (datetime.datetime(2024, 9, 13, 21, 32, 43, 39...             -1

# %%
# Compare oracle values (ground truth) with the values resulting from the LASSO Python test execution
value_df = df.query('TYPE == "value"')
oracle_df = df.query('TYPE == "oracle"')

merged_df = pd.merge(value_df, oracle_df, on=['EXECUTIONID', 'ABSTRACTIONID', 'SHEETID', 'X', 'Y'])
merged_df[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
#     ABSTRACTIONID  Y TYPE_x                         VALUE_x  TYPE_y  \
# 0           Task3  1  value                           False  oracle
# 1         Task115  6  value                           False  oracle
# 2         Task104  9  value  [['"green"', '"orange"'], ['"b  oracle
# 3          Task68  6  value                           False  oracle
# 4           Task2  4  value                      ('5', '4')  oracle
# ..            ... ..    ...                             ...     ...
# 203        Task11  2  value                             bcd  oracle
# 204        Task56  3  value                            True  oracle
# 205        Task74  9  value                           False  oracle
# 206        Task67  2  value                          115975  oracle
# 207        Task96  1  value                               4  oracle
#
#                             VALUE_y
# 0                             False
# 1                             False
# 2    [["'green'", "'orange'"], ["'b
# 3                             False
# 4                        {'5', '4'}
# ..                              ...
# 203                             bcd
# 204                            True
# 205                           False
# 206                          115975
# 207                               4
#
# [208 rows x 6 columns]

# %%
# Cases were return value and oracle value are different
merged_df.query('VALUE_x != VALUE_y')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
#     ABSTRACTIONID   Y TYPE_x                         VALUE_x  TYPE_y  \
# 2         Task104   9  value  [['"green"', '"orange"'], ['"b  oracle
# 4           Task2   4  value                      ('5', '4')  oracle
# 5          Task75  12  value                   [(5, 25, 30)]  oracle
# 12         Task88   9  value  Counter({5: 3, 6: 2, 7: 2, 4:   oracle
# 16        Task103   1  value                    UNSUCCESSFUL  oracle
# 19          Task2  12  value                    ('13', '14')  oracle
# 28        Task118   4  value  ['"lists', 'tuples', 'strings"  oracle
# 35        Task105   2  value                    UNSUCCESSFUL  oracle
# 50        Task108  15  value  ['1', '10', '12', '14', '14',   oracle
# 53         Task87  10  value  {'L': 'Lavender', 'B': 'Black'  oracle
# 60         Task75  18  value                    [(8, 16, 4)]  oracle
# 68        Task118   2  value     ['"python', 'programming"']  oracle
# 79         Task88   6  value  Counter({1: 3, 3: 3, 4: 3, 2:   oracle
# 83          Task2   8  value                      ('3', '4')  oracle
# 90        Task108   5  value  ['11', '110', '15', '154', '19  oracle
# 104         Task2   8  value                      ('3', '4')  oracle
# 106       Task109   2  value                               3  oracle
# 110        Task80   3  value                            84.0  oracle
# 112        Task14   3  value                             1.0  oracle
# 117        Task12   9  value                    UNSUCCESSFUL  oracle
# 119       Task102   3  value           'programmingLanguage'  oracle
# 122        Task97  18  value  {'20': 2, '30': 2, '40': 2, '1  oracle
# 138       Task109   1  value                               2  oracle
# 141        Task80   2  value                            56.0  oracle
# 144        Task14   2  value                             6.0  oracle
# 145       Task105   6  value                    UNSUCCESSFUL  oracle
# 146        Task87  15  value  {'G': 'Green', 'W': 'White', '  oracle
# 148        Task75   6  value                   [(6, 24, 12)]  oracle
# 150       Task102   2  value                'pythonLanguage'  oracle
# 156        Task88   3  value  Counter({10: 4, 20: 4, 40: 2,   oracle
# 163        Task80   1  value                            35.0  oracle
# 165        Task14   1  value                           240.0  oracle
# 168       Task103   3  value                    UNSUCCESSFUL  oracle
# 175       Task102   1  value                 'pythonProgram'  oracle
# 177        Task67   3  value  677568532064582432258148306837  oracle
# 179       Task118   6  value     ['"write', 'a', 'program"']  oracle
# 180       Task108  10  value  ['1', '1', '11', '12', '2', '3  oracle
# 183        Task87   5  value  {'O': 'Orange', 'W': 'White',   oracle
# 186         Task2   4  value                      ('5', '4')  oracle
# 192       Task104  27  value  [['"gold"', '"zilver"'], ['"al  oracle
# 195       Task105   4  value                    UNSUCCESSFUL  oracle
# 198       Task103   2  value                    UNSUCCESSFUL  oracle
# 200         Task2  12  value                    ('14', '13')  oracle
# 202       Task104  18  value  [['" red "', '"green"'], ['" b  oracle
#
#                             VALUE_y
# 2    [["'green'", "'orange'"], ["'b
# 4                        {'5', '4'}
# 5                       (5, 25, 30)
# 12   {10: 1, 5: 3, 6: 2, 7: 2, 4: 2
# 16                                4
# 19                     {'13', '14'}
# 28   ["'lists'", "'tuples'", "'stri
# 35                                2
# 50   ['1', '2', '3', '4', '7', '8',
# 53   {'W': 'White', 'P': 'Pink', 'B
# 60                       (8, 16, 4)
# 68    ["'python'", "'programming'"]
# 79         {1: 3, 2: 2, 3: 3, 4: 3}
# 83                       {'3', '4'}
# 90   ['4', '5', '11', '15', '19', '
# 104                      {'3', '4'}
# 106                               4
# 110                              84
# 112                               1
# 117  [[1, 1, 1], [1, 2, 3], [2, 4,
# 119           'ProgrammingLanguage'
# 122  {20: 2, 30: 2, 40: 2, 17: 1, 1
# 138                               3
# 141                              56
# 144                               6
# 145                               3
# 146  {'B': 'Black', 'P': 'Pink', 'R
# 148                     (6, 24, 12)
# 150                'PythonLanguage'
# 156  {10: 4, 20: 4, 40: 2, 50: 2, 3
# 163                              35
# 165                             240
# 168                              26
# 175                 'PythonProgram'
# 177            6.77568532064582e+54
# 179  ["'write'", "'a'", "'program'"
# 180  ['1', '1', '2', '3', '4', '5',
# 183  {'B': 'Black', 'R': 'Red', 'P'
# 186                      {'5', '4'}
# 192  [["'gold'", "'zilver'"], ["'al
# 195                               0
# 198                              11
# 200                    {'14', '13'}
# 202  [["' red '", "'green'"], ["' b

# %%
# Cases were return value and oracle value are different
merged_df.query('VALUE_x != VALUE_y')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
#     ABSTRACTIONID   Y TYPE_x                         VALUE_x  TYPE_y  \
# 2         Task104   9  value  [['"green"', '"orange"'], ['"b  oracle
# 4           Task2   4  value                      ('5', '4')  oracle
# 5          Task75  12  value                   [(5, 25, 30)]  oracle
# 12         Task88   9  value  Counter({5: 3, 6: 2, 7: 2, 4:   oracle
# 16        Task103   1  value                    UNSUCCESSFUL  oracle
# 19          Task2  12  value                    ('13', '14')  oracle
# 28        Task118   4  value  ['"lists', 'tuples', 'strings"  oracle
# 35        Task105   2  value                    UNSUCCESSFUL  oracle
# 50        Task108  15  value  ['1', '10', '12', '14', '14',   oracle
# 53         Task87  10  value  {'L': 'Lavender', 'B': 'Black'  oracle
# 60         Task75  18  value                    [(8, 16, 4)]  oracle
# 68        Task118   2  value     ['"python', 'programming"']  oracle
# 79         Task88   6  value  Counter({1: 3, 3: 3, 4: 3, 2:   oracle
# 83          Task2   8  value                      ('3', '4')  oracle
# 90        Task108   5  value  ['11', '110', '15', '154', '19  oracle
# 104         Task2   8  value                      ('3', '4')  oracle
# 106       Task109   2  value                               3  oracle
# 110        Task80   3  value                            84.0  oracle
# 112        Task14   3  value                             1.0  oracle
# 117        Task12   9  value                    UNSUCCESSFUL  oracle
# 119       Task102   3  value           'programmingLanguage'  oracle
# 122        Task97  18  value  {'20': 2, '30': 2, '40': 2, '1  oracle
# 138       Task109   1  value                               2  oracle
# 141        Task80   2  value                            56.0  oracle
# 144        Task14   2  value                             6.0  oracle
# 145       Task105   6  value                    UNSUCCESSFUL  oracle
# 146        Task87  15  value  {'G': 'Green', 'W': 'White', '  oracle
# 148        Task75   6  value                   [(6, 24, 12)]  oracle
# 150       Task102   2  value                'pythonLanguage'  oracle
# 156        Task88   3  value  Counter({10: 4, 20: 4, 40: 2,   oracle
# 163        Task80   1  value                            35.0  oracle
# 165        Task14   1  value                           240.0  oracle
# 168       Task103   3  value                    UNSUCCESSFUL  oracle
# 175       Task102   1  value                 'pythonProgram'  oracle
# 177        Task67   3  value  677568532064582432258148306837  oracle
# 179       Task118   6  value     ['"write', 'a', 'program"']  oracle
# 180       Task108  10  value  ['1', '1', '11', '12', '2', '3  oracle
# 183        Task87   5  value  {'O': 'Orange', 'W': 'White',   oracle
# 186         Task2   4  value                      ('5', '4')  oracle
# 192       Task104  27  value  [['"gold"', '"zilver"'], ['"al  oracle
# 195       Task105   4  value                    UNSUCCESSFUL  oracle
# 198       Task103   2  value                    UNSUCCESSFUL  oracle
# 200         Task2  12  value                    ('14', '13')  oracle
# 202       Task104  18  value  [['" red "', '"green"'], ['" b  oracle
#
#                             VALUE_y
# 2    [["'green'", "'orange'"], ["'b
# 4                        {'5', '4'}
# 5                       (5, 25, 30)
# 12   {10: 1, 5: 3, 6: 2, 7: 2, 4: 2
# 16                                4
# 19                     {'13', '14'}
# 28   ["'lists'", "'tuples'", "'stri
# 35                                2
# 50   ['1', '2', '3', '4', '7', '8',
# 53   {'W': 'White', 'P': 'Pink', 'B
# 60                       (8, 16, 4)
# 68    ["'python'", "'programming'"]
# 79         {1: 3, 2: 2, 3: 3, 4: 3}
# 83                       {'3', '4'}
# 90   ['4', '5', '11', '15', '19', '
# 104                      {'3', '4'}
# 106                               4
# 110                              84
# 112                               1
# 117  [[1, 1, 1], [1, 2, 3], [2, 4,
# 119           'ProgrammingLanguage'
# 122  {20: 2, 30: 2, 40: 2, 17: 1, 1
# 138                               3
# 141                              56
# 144                               6
# 145                               3
# 146  {'B': 'Black', 'P': 'Pink', 'R
# 148                     (6, 24, 12)
# 150                'PythonLanguage'
# 156  {10: 4, 20: 4, 40: 2, 50: 2, 3
# 163                              35
# 165                             240
# 168                              26
# 175                 'PythonProgram'
# 177            6.77568532064582e+54
# 179  ["'write'", "'a'", "'program'"
# 180  ['1', '1', '2', '3', '4', '5',
# 183  {'B': 'Black', 'R': 'Red', 'P'
# 186                      {'5', '4'}
# 192  [["'gold'", "'zilver'"], ["'al
# 195                               0
# 198                              11
# 200                    {'14', '13'}
# 202  [["' red '", "'green'"], ["' b

# %%
# Obtain statistics for the coverage metrics
coverage_df = df.query('TYPE == "metrics_covered_lines_in_function_ratio"')

coverage_df['VALUE'].astype(float).describe()
# Out:
# count    205.000000
# mean      90.966134
# std       18.261631
# min        8.823529
# 25%      100.000000
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: VALUE, dtype: float64

# %%
# Obtain information about the longest execution times
sorted_df = df.sort_values(by='EXECUTIONTIME', ascending=False)
sorted_df.head()
# Out:
#                                EXECUTIONID ABSTRACTIONID  ACTIONID  ARENAID  \
# 1686  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task87       NaN  execute
# 5234  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task87       NaN  execute
# 3715  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task93       NaN  execute
# 4752  6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task93       NaN  execute
# 960   6f41b57d-c704-4331-af4f-b03a54fb8fa7        Task84       NaN  execute
#
#       SHEETID                          SYSTEMID VARIANTID  \
# 1686  87.xlsx  be3dbd04478c98e218868c16d718c964  original
# 5234  87.xlsx  be3dbd04478c98e218868c16d718c964  original
# 3715  93.xlsx  25b10dca3d39feaa7bfe6590266b167c  original
# 4752  93.xlsx  25b10dca3d39feaa7bfe6590266b167c  original
# 960   84.xlsx  926dca20e1489334b93ce64b25a77fcb  original
#
#                                               ADAPTERID  X   Y   TYPE  \
# 1686  0('merge_dictionaries_three', 'merge_dictionar...  0  10  value
# 5234  0('merge_dictionaries_three', 'merge_dictionar...  1  10     op
# 3715                             0('power', 'power', 0)  1   1     op
# 4752                             0('power', 'power', 0)  0   1  value
# 960                        0('sequence', 'sequence', 0)  0   1  value
#
#                                VALUE  \
# 1686  {'L': 'Lavender', 'B': 'Black'
# 5234        merge_dictionaries_three
# 3715                           power
# 4752                              81
# 960                                6
#
#                                                RAWVALUE  \
# 1686  {'L': 'Lavender', 'B': 'Black', 'G': 'Green', ...
# 5234                           merge_dictionaries_three
# 3715                                              power
# 4752                                                 81
# 960                                                   6
#
#                            VALUETYPE  \
# 1686                  <class 'dict'>
# 5234                        function
# 3715                        function
# 4752  <class 'numpy.ma.MaskedArray'>
# 960                    <class 'int'>
#
#                                            LASTMODIFIED  EXECUTIONTIME
# 1686  (datetime.datetime(2024, 9, 13, 21, 34, 12, 32...          40279
# 5234  (datetime.datetime(2024, 9, 13, 21, 34, 12, 32...          40279
# 3715  (datetime.datetime(2024, 9, 13, 21, 35, 25, 76...           7572
# 4752  (datetime.datetime(2024, 9, 13, 21, 35, 25, 76...           7572
# 960   (datetime.datetime(2024, 9, 13, 21, 33, 43, 88...           5877
