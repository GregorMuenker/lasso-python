# %% [markdown]
# # LASSO Python
# ## MBPP Evaluation Analytics
# This notebook showcases how a data analyst can use LASSO Python to collect dynamic information about Python code implementations.
# By using data from an Apache Ignite cache that was filled by LASSO Python, the analyst can easily deduce interesting information, such as correctness of the code, execution times, or coverage data.
# Both the tests and the Python code implementations used in this example stem from the sanitized Mostly Basic Python Problems (MBPP) dataset. MBPP is a dataset consisting of crowd-sourced Python programming problems. Each task consists of a description, a code solution and multiple test cases. By using LASSO Python, these tests were replicated with the results shown in this notebook. More information on MBPP can be found here: https://github.com/google-research/google-research/tree/master/mbpp

# %%
# Import result csv that was generated by LASSO Python and extracted from the Apache Ignite cache
import pandas as pd

file_path = './evaluation_results.csv'
df = pd.read_csv(file_path)
number_of_tasks = df['ABSTRACTIONID'].nunique()
print(f'Number of tasks: {number_of_tasks}')
df.head()
# Out:
# Number of tasks: 379
#                             EXECUTIONID ABSTRACTIONID     ACTIONID  ARENAID  \
# 0  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task164  PLACEHOLDER  execute
# 1  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task770          NaN  execute
# 2  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task278          NaN  execute
# 3  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task462  PLACEHOLDER  execute
# 4  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task409  PLACEHOLDER  execute
#
#     SHEETID                              SYSTEMID VARIANTID  \
# 0  164.xlsx  c4f56584-1c07-4c11-976c-5976da3991cf  original
# 1  770.xlsx  bafe5016-8d1b-4770-bd1a-ba7cf0630814  original
# 2  278.xlsx  1c5ed937-bae2-4c76-9791-43dbaa7ddf9d  original
# 3  462.xlsx                                   NaN  original
# 4  409.xlsx                                   NaN  original
#
#                                            ADAPTERID  X   Y  \
# 0           0('are_equivalent', 'are_equivalent', 0)  2   3
# 1                 0('odd_num_sum', 'odd_num_sum', 0) -1   3
# 2  0('count_first_elements', 'count_first_element... -1   3
# 3               0('create', 'createPythonObject', 0)  3  62
# 4               0('create', 'createPythonObject', 0)  3   1
#
#                                TYPE   VALUE RAWVALUE      VALUETYPE  \
# 0                       input_value       -        -  <class 'str'>
# 1         metrics_all_lines_in_file    2360     2360  <class 'int'>
# 2  metrics_covered_branches_in_file       3        3  <class 'int'>
# 3                       input_value  orange   orange  <class 'str'>
# 4                       input_value       2        2  <class 'int'>
#
#                                         LASTMODIFIED  EXECUTIONTIME
# 0  (datetime.datetime(2024, 9, 15, 19, 33, 42, 62...             -1
# 1  (datetime.datetime(2024, 9, 15, 19, 44, 38, 85...             -1
# 2  (datetime.datetime(2024, 9, 15, 19, 35, 45, 49...             -1
# 3  (datetime.datetime(2024, 9, 15, 19, 39, 22, 11...             -1
# 4  (datetime.datetime(2024, 9, 15, 19, 37, 32, 32...             -1

# %%
# Compare oracle values (ground truth) with the values resulting from the LASSO Python test execution
value_df = df.query('TYPE == "value"')
oracle_df = df.query('TYPE == "oracle"')

merged_df = pd.merge(value_df, oracle_df, on=['EXECUTIONID', 'ABSTRACTIONID', 'SHEETID', 'X', 'Y'])
merged_df[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
#      ABSTRACTIONID   Y TYPE_x                         VALUE_x  TYPE_y  \
# 0          Task434   3  value                            True  oracle
# 1          Task721  10  value                             6.2  oracle
# 2          Task171   1  value                              25  oracle
# 3          Task436   3  value                        [-1, -6]  oracle
# 4          Task734   6  value                              84  oracle
# ...            ...  ..    ...                             ...     ...
# 1146       Task253   6  value                               2  oracle
# 1147       Task443   4  value                              -9  oracle
# 1148       Task728   4  value                    [25, 45, 65]  oracle
# 1149       Task247   1  value                               5  oracle
# 1150       Task456   3  value  ['deR', 'neerG', 'eulB', 'etih  oracle
#
#                              VALUE_y
# 0                               True
# 1                                6.2
# 2                                 25
# 3                           [-1, -6]
# 4                                 84
# ...                              ...
# 1146                               2
# 1147                              -9
# 1148                    [25, 45, 65]
# 1149                               5
# 1150  ['deR', 'neerG', 'eulB', 'etih
#
# [1151 rows x 6 columns]

# %%
# Cases were return value and oracle value are equal
successful_test_runs = merged_df.query('VALUE_x == VALUE_y')['ABSTRACTIONID'].nunique()
print(f"{successful_test_runs}/{number_of_tasks} tasks with equal return and oracle values ({successful_test_runs/number_of_tasks*100:.2f}%)")
merged_df.query('VALUE_x == VALUE_y')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
# 345/379 tasks with equal return and oracle values (91.03%)
#      ABSTRACTIONID   Y TYPE_x                         VALUE_x  TYPE_y  \
# 0          Task434   3  value                            True  oracle
# 1          Task721  10  value                             6.2  oracle
# 2          Task171   1  value                              25  oracle
# 3          Task436   3  value                        [-1, -6]  oracle
# 4          Task734   6  value                              84  oracle
# ...            ...  ..    ...                             ...     ...
# 1146       Task253   6  value                               2  oracle
# 1147       Task443   4  value                              -9  oracle
# 1148       Task728   4  value                    [25, 45, 65]  oracle
# 1149       Task247   1  value                               5  oracle
# 1150       Task456   3  value  ['deR', 'neerG', 'eulB', 'etih  oracle
#
#                              VALUE_y
# 0                               True
# 1                                6.2
# 2                                 25
# 3                           [-1, -6]
# 4                                 84
# ...                              ...
# 1146                               2
# 1147                              -9
# 1148                    [25, 45, 65]
# 1149                               5
# 1150  ['deR', 'neerG', 'eulB', 'etih
#
# [1027 rows x 6 columns]

# %%
# Cases were return value and oracle value are different
different_return_and_oracle = merged_df.query('VALUE_x != VALUE_y')['ABSTRACTIONID'].nunique()
print(f"{different_return_and_oracle}/{number_of_tasks} tasks with different return and oracle values ({different_return_and_oracle/number_of_tasks*100:.2f}%)")
merged_df.query('VALUE_x != VALUE_y')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
# 49/379 tasks with different return and oracle values (12.93%)
#      ABSTRACTIONID   Y TYPE_x            VALUE_x  TYPE_y  \
# 8          Task744   2  value              False  oracle
# 13          Task80   3  value               84.0  oracle
# 19         Task758  32  value       UNSUCCESSFUL  oracle
# 34         Task391  39  value       UNSUCCESSFUL  oracle
# 40         Task412   6  value       UNSUCCESSFUL  oracle
# ...            ...  ..    ...                ...     ...
# 1101       Task723   9  value       UNSUCCESSFUL  oracle
# 1105       Task419   6  value       UNSUCCESSFUL  oracle
# 1108       Task133   2  value       UNSUCCESSFUL  oracle
# 1123       Task628   1  value  My_Name_is_Dawood  oracle
# 1145       Task295   1  value       UNSUCCESSFUL  oracle
#
#                              VALUE_y
# 8                               True
# 13                                84
# 19    {(10, 20, 30, 40): 1, (60, 70,
# 34    [{None: {'java': 10}}, None, N
# 40                         [2, 4, 6]
# ...                              ...
# 1101                               1
# 1105                             513
# 1108                             -32
# 1123         My%20Name%20is%20Dawood
# 1145                               7
#
# [124 rows x 6 columns]

# %%
# Cases were the return value and oracle value are different but the was not unsuccessful
print(merged_df.query('VALUE_x != "UNSUCCESSFUL" and VALUE_x != VALUE_y')['ABSTRACTIONID'].nunique(), f"/ {number_of_tasks} tasks without errors where oracle and return values are different")
merged_df.query('VALUE_x != "UNSUCCESSFUL" and VALUE_x != VALUE_y')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
# 27 / 379 tasks without errors where oracle and return values are different
#      ABSTRACTIONID   Y TYPE_x                         VALUE_x  TYPE_y  \
# 8          Task744   2  value                           False  oracle
# 13          Task80   3  value                            84.0  oracle
# 65         Task618   8  value                      [3.0, 0.5]  oracle
# 77          Task87  15  value  {'G': 'Green', 'W': 'White', '  oracle
# 81         Task606   1  value              1.5707963267948966  oracle
# 118        Task742   3  value              173.20508075688772  oracle
# 141         Task80   2  value                            56.0  oracle
# 145        Task465   6  value       {'c1': 'Red', 'c2': 'c3'}  oracle
# 148        Task746   2  value              31.808625617596654  oracle
# 174        Task117  22  value  [(4.0, 4.0), (2.0, 27.0), (4.1  oracle
# 189        Task783   4  value  (120.0, 100.0, 84.313725490196  oracle
# 216         Task88   3  value  Counter({10: 4, 20: 4, 40: 2,   oracle
# 237        Task590   3  value  ((5.0, 0.9272952180016122), (-  oracle
# 248        Task415   6  value                               5  oracle
# 250        Task554   6  value                        [10, 12]  oracle
# 258         Task87   5  value  {'O': 'Orange', 'W': 'White',   oracle
# 260        Task396   3  value                           Valid  oracle
# 270         Task80   1  value                            35.0  oracle
# 373        Task742   1  value              15.588457268119894  oracle
# 387        Task622   3  value                            16.0  oracle
# 448         Task67   3  value  677568532064582432258148306837  oracle
# 466        Task783   2  value                 (0, 0.0, 100.0)  oracle
# 499        Task267   3  value                             120  oracle
# 510        Task252   6  value                      (5.0, 0.0)  oracle
# 518        Task117  11  value  [(3.0, 4.0), (1.0, 26.45), (7.  oracle
# 557         Task88   9  value  Counter({5: 3, 6: 2, 7: 2, 4:   oracle
# 576        Task618   4  value                 [4.0, 2.5, 2.0]  oracle
# 587        Task744   6  value                           False  oracle
# 599        Task731   3  value              1521.8090132193388  oracle
# 601        Task126   3  value                             NaN  oracle
# 619        Task267   2  value                              56  oracle
# 630        Task618  12  value       [1.8, 1.7142857142857142]  oracle
# 642        Task415   3  value                             168  oracle
# 643        Task554   3  value                       [2, 4, 6]  oracle
# 697        Task622   9  value                            25.0  oracle
# 715         Task87  10  value  {'L': 'lavender', 'B': 'Black'  oracle
# 731        Task126   2  value                             NaN  oracle
# 744        Task599   4  value                      (120, 8.0)  oracle
# 754        Task267   1  value                              20  oracle
# 764        Task293   2  value                             5.0  oracle
# 767        Task252   4  value                      (4.0, 0.0)  oracle
# 804        Task422   3  value                             1.0  oracle
# 843        Task628   3  value                   I_love_Coding  oracle
# 874        Task465   9  value     {'c1': 'c2', 'Green': 'c3'}  oracle
# 876        Task432   2  value                            15.0  oracle
# 879        Task731   1  value              204.20352248333654  oracle
# 880        Task126   1  value                             NaN  oracle
# 934        Task606   3  value              2.0943951023931953  oracle
# 941        Task422   2  value                            12.0  oracle
# 965         Task88   6  value  Counter({1: 3, 3: 3, 4: 3, 2:   oracle
# 977        Task628   2  value               I_am_a_Programmer  oracle
# 985        Task117  33  value  [(6.0, 78.0), (5.0, 26.45), (1  oracle
# 1003       Task415   9  value                               6  oracle
# 1004       Task554   9  value                             [8]  oracle
# 1011       Task574   2  value              226.18800000000002  oracle
# 1019       Task432   1  value                            20.0  oracle
# 1051       Task252   2  value                      (1.0, 0.0)  oracle
# 1076       Task783   6  value  (149.26829268292684, 95.348837  oracle
# 1077       Task606   2  value              1.0471975511965976  oracle
# 1123       Task628   1  value               My_Name_is_Dawood  oracle
#
#                              VALUE_y
# 8                               True
# 13                                84
# 65                          [3, 0.5]
# 77    {'B': 'Black', 'P': 'Pink', 'R
# 81                 1.570796326794897
# 118                173.2050807568877
# 141                               56
# 145                    {'c1': 'Red'}
# 148                31.80862561759665
# 174   [(4, 4), (2, 27), (4.12, 9), (
# 189    (120, 100, 84.31372549019608)
# 216   {10: 4, 20: 4, 40: 2, 50: 2, 3
# 237   ((5, 0.9272952180016122), '-2+
# 248                         (-4, -6)
# 250                         [11, 13]
# 258   {'B': 'Black', 'R': 'Red', 'P'
# 260                          Invalid
# 270                               35
# 373                15.58845726811989
# 387                               16
# 448            6.775685320645824e+54
# 466                      (0, 0, 100)
# 499                               84
# 510                           (5, 0)
# 518   [(3, 4), (1, 26.45), (7.32, 8)
# 557   {10: 1, 5: 3, 6: 2, 7: 2, 4: 2
# 576                      [4, 2.5, 2]
# 587                             True
# 599                1521.809013219339
# 601                                3
# 619                               35
# 630         [1.8, 1.714285714285714]
# 642                           (7, 8)
# 643                        [1, 3, 5]
# 697                               25
# 715   {'W': 'White', 'P': 'Pink', 'B
# 731                               93
# 744                         (120, 8)
# 754                               10
# 764                                5
# 767                           (4, 0)
# 804                                1
# 843                I%20love%20Coding
# 874                  {'c2': 'Green'}
# 876                               15
# 879                204.2035224833365
# 880                                6
# 934                2.094395102393195
# 941                               12
# 965         {1: 3, 2: 2, 3: 3, 4: 3}
# 977          I%20am%20a%20Programmer
# 985   [(6, 78), (5, 26.45), (1.33, 4
# 1003                          (2, 3)
# 1004                       [7, 9, 1]
# 1011                         226.188
# 1019                              20
# 1051                          (1, 0)
# 1076  (149.2682926829268, 95.3488372
# 1077               1.047197551196598
# 1123         My%20Name%20is%20Dawood

# %%
# Cases were the execution was unsuccessful
print(merged_df.query('VALUE_x == "UNSUCCESSFUL"')['ABSTRACTIONID'].nunique(), "tasks that (partially) failed")
merged_df.query('VALUE_x == "UNSUCCESSFUL"')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]
# Out:
# 22 tasks that (partially) failed
#      ABSTRACTIONID   Y TYPE_x       VALUE_x  TYPE_y  \
# 19         Task758  32  value  UNSUCCESSFUL  oracle
# 34         Task391  39  value  UNSUCCESSFUL  oracle
# 40         Task412   6  value  UNSUCCESSFUL  oracle
# 42         Task558   1  value  UNSUCCESSFUL  oracle
# 43         Task105   4  value  UNSUCCESSFUL  oracle
# ...            ...  ..    ...           ...     ...
# 1096       Task123   3  value  UNSUCCESSFUL  oracle
# 1101       Task723   9  value  UNSUCCESSFUL  oracle
# 1105       Task419   6  value  UNSUCCESSFUL  oracle
# 1108       Task133   2  value  UNSUCCESSFUL  oracle
# 1145       Task295   1  value  UNSUCCESSFUL  oracle
#
#                              VALUE_y
# 19    {(10, 20, 30, 40): 1, (60, 70,
# 34    [{None: {'java': 10}}, None, N
# 40                         [2, 4, 6]
# 42                                 1
# 43                                 0
# ...                              ...
# 1096                               0
# 1101                               1
# 1105                             513
# 1108                             -32
# 1145                               7
#
# [64 rows x 6 columns]

# %%
print("Task identifiers of tasks that (partially) failed:")
set(merged_df.query('VALUE_x == "UNSUCCESSFUL"')[['ABSTRACTIONID', 'Y', 'TYPE_x', 'VALUE_x', 'TYPE_y', 'VALUE_y']]["ABSTRACTIONID"])
# Out:
# Task identifiers of tasks that (partially) failed:
# {'Task105',
#  'Task123',
#  'Task129',
#  'Task133',
#  'Task142',
#  'Task172',
#  'Task295',
#  'Task391',
#  'Task398',
#  'Task412',
#  'Task419',
#  'Task558',
#  'Task614',
#  'Task615',
#  'Task723',
#  'Task724',
#  'Task735',
#  'Task757',
#  'Task758',
#  'Task779',
#  'Task799',
#  'Task805'}

# %%
# Obtain statistics for the coverage metrics
coverage_df = df.query('TYPE == "metrics_covered_lines_in_function_ratio"')

coverage_df['VALUE'].astype(float).describe()
# Out:
# count    1102.000000
# mean       92.805384
# std        14.358189
# min         8.823529
# 25%        93.548387
# 50%       100.000000
# 75%       100.000000
# max       100.000000
# Name: VALUE, dtype: float64

# %%
# Obtain information about the longest execution times
sorted_df = df.sort_values(by='EXECUTIONTIME', ascending=False)
sorted_df.head()
# Out:
#                                 EXECUTIONID ABSTRACTIONID     ACTIONID  \
# 29352  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task583  PLACEHOLDER
# 34301  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task583  PLACEHOLDER
# 25146  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task583  PLACEHOLDER
# 19355  aeb97361-e15b-4ce8-9d4a-d94f19e82717       Task583  PLACEHOLDER
# 34528  aeb97361-e15b-4ce8-9d4a-d94f19e82717        Task84  PLACEHOLDER
#
#        ARENAID   SHEETID                              SYSTEMID VARIANTID  \
# 29352  execute  583.xlsx  b67e71c9-407f-4310-9e63-773268541061  original
# 34301  execute  583.xlsx  b67e71c9-407f-4310-9e63-773268541061  original
# 25146  execute  583.xlsx  b67e71c9-407f-4310-9e63-773268541061  original
# 19355  execute  583.xlsx  b67e71c9-407f-4310-9e63-773268541061  original
# 34528  execute   84.xlsx  122e1fa5-4fd5-4a40-9194-27d5d492c4fd  original
#
#                                       ADAPTERID  X  Y   TYPE           VALUE  \
# 29352  0('catalan_number', 'catalan_number', 0)  0  1  value           16796
# 34301  0('catalan_number', 'catalan_number', 0)  1  1     op  catalan_number
# 25146  0('catalan_number', 'catalan_number', 0)  0  2  value            4862
# 19355  0('catalan_number', 'catalan_number', 0)  1  2     op  catalan_number
# 34528              0('sequence', 'sequence', 0)  0  1  value               6
#
#              RAWVALUE      VALUETYPE  \
# 29352           16796  <class 'int'>
# 34301  catalan_number       function
# 25146            4862  <class 'int'>
# 19355  catalan_number       function
# 34528               6  <class 'int'>
#
#                                             LASTMODIFIED  EXECUTIONTIME
# 29352  (datetime.datetime(2024, 9, 15, 19, 40, 56, 58...          22061
# 34301  (datetime.datetime(2024, 9, 15, 19, 40, 56, 58...          22061
# 25146  (datetime.datetime(2024, 9, 15, 19, 40, 56, 58...           6341
# 19355  (datetime.datetime(2024, 9, 15, 19, 40, 56, 58...           6341
# 34528  (datetime.datetime(2024, 9, 15, 19, 32, 11, 15...           1091
